# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fadilahrahmadiah/flyrank-ml-workspace/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# # 1. My lane (or freestyle) and why
# Lane 1: Ranking Signal Analysis.
# I chose this lane because understanding which content and search signals actually correlate with visibility and traffic helps cut through guesswork. Instead of randomly editing pages, we can analyze historical data to see which measurable factors truly drive performance, providing a solid, evidence-based starting point for content optimization.

# %%
# 1. My lane (or freestyle) and why

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# - **Decision improved:** Deciding which content attributes or signals to focus on when evaluating website performance and visibility health.
# - **Who acts on it:** SEO Strategists and Content Analysts.
# - **Action taken:** Prioritizing optimization efforts around the signals proven to have the strongest relationship with traffic retention, rather than chasing ineffective metrics.
# - **Cost of a wrong call:** If our signal analysis is flawed, teams might spend valuable resources optimizing the wrong features (e.g., unnecessarily rewriting long-form content when the real issue is positioning or freshness), leading to wasted time and stagnant traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Calculate 2-3 real numbers to support Lane 1
total_pages = df.shape[0]
avg_impressions = df["impressions_90d"].mean()
avg_word_count = df["word_count"].mean()

print(f"Total content items analyzed: {total_pages:,}")
print(f"Average 90-day impressions per page: {avg_impressions:.1f}")
print(f"Average word count per page: {avg_word_count:.1f}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1033/3031422072.py in <cell line: 0>()
#       2
#       3 # Load the starter dataset
# ----> 4 df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
#       5
#       6 # Calculate 2-3 real numbers to support Lane 1
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
